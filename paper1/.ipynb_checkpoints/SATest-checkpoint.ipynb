# %% [markdown]
# ### Episode 1
# 问题：$F(x,y)=5cos(xy)+xy+y^3$

# %%
using Plots
pyplot(leg=false, ticks=nothing)
# Out:
# Plots.PyPlotBackend()

# %%
function objFunc(vec)
    x, y = vec
    return 5*cos(x*y) + x*y + y^3
end
# Out:
# objFunc (generic function with 1 method)

# %%
x0 = -5:0.1:5
y0 = -5:0.1:5
f(x,y) = objFunc((x,y))
p = plot(x0, y0, f, st = [:surface])
